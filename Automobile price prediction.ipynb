# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='drive/My Drive/Dataset'

# %%
data = pd.read_csv('/content/drive/My Drive/Dataset/Automobile .csv')

# %%
data.head()
# Out:
#    \ normalized-losses         make  ... city-mpg highway-mpg  price
# 0  3                 ?  alfa-romero  ...       21          27  13495
# 1  3                 ?  alfa-romero  ...       21          27  16500
# 2  1                 ?  alfa-romero  ...       19          26  16500
# 3  2               164         audi  ...       24          30  13950
# 4  2               164         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
data
# Out:
#      \ normalized-losses         make  ... city-mpg highway-mpg  price
# 0    3                 ?  alfa-romero  ...       21          27  13495
# 1    3                 ?  alfa-romero  ...       21          27  16500
# 2    1                 ?  alfa-romero  ...       19          26  16500
# 3    2               164         audi  ...       24          30  13950
# 4    2               164         audi  ...       18          22  17450
# ..  ..               ...          ...  ...      ...         ...    ...
# 200 -1                95        volvo  ...       23          28  16845
# 201 -1                95        volvo  ...       19          25  19045
# 202 -1                95        volvo  ...       18          23  21485
# 203 -1                95        volvo  ...       26          27  22470
# 204 -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   \                  205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# positively corelated:curb-size, engine-size, horsepower, width
#
# negatively corelated:city-mpg,highway-mpg,peak-rpm

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='fuel-type',data=data)

# %% [markdown]
# Most preferred fuel type is gas

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='make',data=data)

# %%
plt.figure(figsize=(25,12))
sns.jointplot(x='peak-rpm', y='price', data=data, color='green')

# %%
data = data.replace(to_replace = '?', value = 0) 
data['price'] =data['price'].astype('int64')
data
# Out:
#      \ normalized-losses         make  ... city-mpg highway-mpg  price
# 0    3                 0  alfa-romero  ...       21          27  13495
# 1    3                 0  alfa-romero  ...       21          27  16500
# 2    1                 0  alfa-romero  ...       19          26  16500
# 3    2               164         audi  ...       24          30  13950
# 4    2               164         audi  ...       18          22  17450
# ..  ..               ...          ...  ...      ...         ...    ...
# 200 -1                95        volvo  ...       23          28  16845
# 201 -1                95        volvo  ...       19          25  19045
# 202 -1                95        volvo  ...       18          23  21485
# 203 -1                95        volvo  ...       26          27  22470
# 204 -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
plt.figure(figsize=(20,6))
sns.boxplot(x="engine-location", y="price", data=data)

# %%
plt.figure(figsize=(25,10))
sns.boxplot(x="make", y="price", data=data)

# %% [markdown]
# Mercedez-Benz ,BMW, Jaguar, Porshe produces expensive cars more than 25000
#
# cheverolet,dodge, honda,mitbushi, nissan,plymouth subaru,toyata produces budget models with lower prices
#
# most of the cars comapany produces car in range below 25000

# %%
plt.figure(figsize=(25,10))
sns.catplot(data=data, x="num-of-cylinders", y="price",kind="violin")

# %%
sns.pairplot(data[["city-mpg","width", "horsepower","peak-rpm" ,"engine-size", "curb-weight","price", "fuel-type","highway-mpg"]], hue="fuel-type", diag_kind="hist")

# %%
data
# Out:
#      \ normalized-losses         make  ... city-mpg highway-mpg  price
# 0    3                 0  alfa-romero  ...       21          27  13495
# 1    3                 0  alfa-romero  ...       21          27  16500
# 2    1                 0  alfa-romero  ...       19          26  16500
# 3    2               164         audi  ...       24          30  13950
# 4    2               164         audi  ...       18          22  17450
# ..  ..               ...          ...  ...      ...         ...    ...
# 200 -1                95        volvo  ...       23          28  16845
# 201 -1                95        volvo  ...       19          25  19045
# 202 -1                95        volvo  ...       18          23  21485
# 203 -1                95        volvo  ...       26          27  22470
# 204 -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %% [markdown]
# Vehicle Mileage decrease as increase in Horsepower , engine-size, Curb Weight
#
# city-mpg increases with highway-mpg
#
# As horsepower increase the engine size increases
#
# price increases with increase in width
#
# Curbweight increases with the increase in Engine Size

# %% [markdown]
# DATA CLEANING

# %%
data
# Out:
#      \ normalized-losses         make  ... city-mpg highway-mpg  price
# 0    3                 0  alfa-romero  ...       21          27  13495
# 1    3                 0  alfa-romero  ...       21          27  16500
# 2    1                 0  alfa-romero  ...       19          26  16500
# 3    2               164         audi  ...       24          30  13950
# 4    2               164         audi  ...       18          22  17450
# ..  ..               ...          ...  ...      ...         ...    ...
# 200 -1                95        volvo  ...       23          28  16845
# 201 -1                95        volvo  ...       19          25  19045
# 202 -1                95        volvo  ...       18          23  21485
# 203 -1                95        volvo  ...       26          27  22470
# 204 -1                95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
df_temp = data[data['normalized-losses']!='?']
normalised_mean = df_temp['normalized-losses'].astype(int).mean()
data['normalized-losses'] = data['normalized-losses'].replace('?',normalised_mean).astype(int)

df_temp = data[data['horsepower']!='?']
normalised_mean = df_temp['horsepower'].astype(int).mean()
data['horsepower'] = data['horsepower'].replace('?',normalised_mean).astype(int)

df_temp = data[data['peak-rpm']!='?']
normalised_mean = df_temp['peak-rpm'].astype(int).mean()
data['peak-rpm'] = data['peak-rpm'].replace('?',normalised_mean).astype(int)

df_temp = data[data['bore']!='?']
normalised_mean = df_temp['bore'].astype(float).mean()
data['bore'] = data['bore'].replace('?',normalised_mean).astype(float)

df_temp = data[data['stroke']!='?']
normalised_mean = df_temp['stroke'].astype(float).mean()
data['stroke'] = data['stroke'].replace('?',normalised_mean).astype(float)

data['num-of-doors'] = data['num-of-doors'].replace('?','four')

# %%
data
# Out:
#      \  normalized-losses         make  ... city-mpg highway-mpg  price
# 0    3                  0  alfa-romero  ...       21          27  13495
# 1    3                  0  alfa-romero  ...       21          27  16500
# 2    1                  0  alfa-romero  ...       19          26  16500
# 3    2                164         audi  ...       24          30  13950
# 4    2                164         audi  ...       18          22  17450
# ..  ..                ...          ...  ...      ...         ...    ...
# 200 -1                 95        volvo  ...       23          28  16845
# 201 -1                 95        volvo  ...       19          25  19045
# 202 -1                 95        volvo  ...       18          23  21485
# 203 -1                 95        volvo  ...       26          27  22470
# 204 -1                 95        volvo  ...       19          25  22625
#
# [205 rows x 26 columns]

# %%
data = pd.get_dummies(data, drop_first=True)
data.head()
# Out:
#    \  normalized-losses  ...  fuel-system_spdi  fuel-system_spfi
# 0  3                  0  ...                 0                 0
# 1  3                  0  ...                 0                 0
# 2  1                  0  ...                 0                 0
# 3  2                164  ...                 0                 0
# 4  2                164  ...                 0                 0
#
# [5 rows x 67 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 67 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   \                        205 non-null    int64
#  1   normalized-losses        205 non-null    int64
#  2   wheel-base               205 non-null    float64
#  3   length                   205 non-null    float64
#  4   width                    205 non-null    float64
#  5   height                   205 non-null    float64
#  6   curb-weight              205 non-null    int64
#  7   engine-size              205 non-null    int64
#  8   bore                     205 non-null    float64
#  9   stroke                   205 non-null    float64
#  10  compression-ratio        205 non-null    float64
#  11  horsepower               205 non-null    int64
#  12  peak-rpm                 205 non-null    int64
#  13  city-mpg                 205 non-null    int64
# ...

# %%
X = data.drop('price', axis=1)
y = data['price']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %% [markdown]
# # **LINEAR REGRESSION**

# %% [markdown]
# TRAINING

# %%
from sklearn.linear_model import LinearRegression

lm = LinearRegression()

lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# TESTING

# %%
predictions = lm.predict( X_test)

# %%
print(r2_score(y_test, predictions))
# Out:
# 0.7838637632002385

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 2262.5405807851876
# MSE: 15993175.03169139
# RMSE: 3999.146787965077

# %%
sns.distplot((y_test-predictions),bins=50);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # **DECISION TREE REGRESSOR**

# %% [markdown]
# **TRAINING**

# %%
from sklearn.tree import DecisionTreeRegressor
mod = DecisionTreeRegressor()
mod.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %% [markdown]
# **TESTING**

# %%
pred = mod.predict(X_test)

# %%
print(r2_score(y_test, pred))
# Out:
# 0.8052639760643846

# %%
plt.scatter(y_test,pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pred))
print('MSE:', metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE: 2499.3064516129034
# MSE: 20748780.43548387
# RMSE: 4555.082923008523

# %%
sns.distplot((y_test-pred),bins=50);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # **RANDOM FOREST REGRESSOR**

# %% [markdown]
# **TRAINING**

# %%
from sklearn.ensemble import RandomForestRegressor
model1 = RandomForestRegressor()
model1.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# **TESTING**

# %%
pre = model1.predict(X_test)

# %%
print(r2_score(y_test, pre))
# Out:
# 0.8907359153397715

# %%
plt.scatter(y_test,pre)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('MAE:', metrics.mean_absolute_error(y_test, pre))
print('MSE:', metrics.mean_squared_error(y_test, pre))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pre)))
# Out:
# MAE: 1879.8193452380951
# MSE: 12388095.540767146
# RMSE: 3519.672646819182

# %%
sns.distplot((y_test-pre),bins=50);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
